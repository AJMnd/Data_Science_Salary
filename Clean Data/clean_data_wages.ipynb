# %%
import pandas as pd
import numpy as np

# %%
#file_path = "clean_general_wages.csv"

file_path = "clean_general_wages"
clean_wages_df= pd.read_csv("C:/Users/petec/Desktop/school/groupproject/Data_Science_Salary/clean_data/clean_general_wages.csv")
clean_wages_df
# Out:
#        Age          Workclass  fnlgwt    Education  Education Num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32556   27            Private  257302   Assoc-acdm             12
# 32557   40            Private  154374      HS-grad              9
# 32558   58            Private  151910      HS-grad              9
# 32559   22            Private  201490      HS-grad              9
# 32560   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital Status          Occupation    Relationship    Race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
clean_wages_df.drop(['Marital Status','Age','Workclass'],axis=1, inplace=True)
clean_wages_df
# Out:
#        fnlgwt    Education  Education Num          Occupation    Race  \
# 0       77516    Bachelors             13        Adm-clerical   White
# 1       83311    Bachelors             13     Exec-managerial   White
# 2      215646      HS-grad              9   Handlers-cleaners   White
# 3      234721         11th              7   Handlers-cleaners   Black
# 4      338409    Bachelors             13      Prof-specialty   Black
# ...       ...          ...            ...                 ...     ...
# 32556  257302   Assoc-acdm             12        Tech-support   White
# 32557  154374      HS-grad              9   Machine-op-inspct   White
# 32558  151910      HS-grad              9        Adm-clerical   White
# 32559  201490      HS-grad              9        Adm-clerical   White
# 32560  287927      HS-grad              9     Exec-managerial   White
#
#            Sex  Capital Gain  Capital Loss  Hours/Week         Country  \
# ...

# %%
clean_wages_df.drop(['fnlgwt','Education Num','Capital Gain','Capital Loss', 'Country'],axis=1, inplace=True)
clean_wages_df
# Out:
#          Education          Occupation    Race      Sex  Hours/Week  \
# 0        Bachelors        Adm-clerical   White     Male          40
# 1        Bachelors     Exec-managerial   White     Male          13
# 2          HS-grad   Handlers-cleaners   White     Male          40
# 3             11th   Handlers-cleaners   Black     Male          40
# 4        Bachelors      Prof-specialty   Black   Female          40
# ...            ...                 ...     ...      ...         ...
# 32556   Assoc-acdm        Tech-support   White   Female          38
# 32557      HS-grad   Machine-op-inspct   White     Male          40
# 32558      HS-grad        Adm-clerical   White   Female          40
# 32559      HS-grad        Adm-clerical   White     Male          20
# 32560      HS-grad     Exec-managerial   White   Female          40
#
#       Above/Below 50K
# 0               <=50K
# 1               <=50K
# 2               <=50K
# 3               <=50K
# 4               <=50K
# ...

# %%
clean_wages_df.drop(['Race'],axis=1, inplace=True)
clean_wages_df
# Out:
#          Education          Occupation      Sex  Hours/Week Above/Below 50K
# 0        Bachelors        Adm-clerical     Male          40           <=50K
# 1        Bachelors     Exec-managerial     Male          13           <=50K
# 2          HS-grad   Handlers-cleaners     Male          40           <=50K
# 3             11th   Handlers-cleaners     Male          40           <=50K
# 4        Bachelors      Prof-specialty   Female          40           <=50K
# ...            ...                 ...      ...         ...             ...
# 32556   Assoc-acdm        Tech-support   Female          38           <=50K
# 32557      HS-grad   Machine-op-inspct     Male          40            >50K
# 32558      HS-grad        Adm-clerical   Female          40           <=50K
# 32559      HS-grad        Adm-clerical     Male          20           <=50K
# 32560      HS-grad     Exec-managerial   Female          40            >50K
#
# [32561 rows x 5 columns]
