# %%
import pandas as pd

# %%
file_path = "wages/national_M2021_dl.csv"
wages_df = pd.read_csv(file_path)
wages_df
# Out:
#       AREA AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 0       99       U.S.          1         US      0  Cross-industry
# 1       99       U.S.          1         US      0  Cross-industry
# 2       99       U.S.          1         US      0  Cross-industry
# 3       99       U.S.          1         US      0  Cross-industry
# 4       99       U.S.          1         US      0  Cross-industry
# ...    ...        ...        ...        ...    ...             ...
# 1398    99       U.S.          1         US      0  Cross-industry
# 1399    99       U.S.          1         US      0  Cross-industry
# 1400    99       U.S.          1         US      0  Cross-industry
# 1401    99       U.S.          1         US      0  Cross-industry
# 1402    99       U.S.          1         US      0  Cross-industry
#
#              I_GROUP  OWN_CODE OCC_CODE  \
# 0     cross-industry      1235  00-0000
# 1     cross-industry      1235  11-0000
# ...

# %%
print(wages_df["OCC_TITLE"].count)
# Out:
# <bound method Series.count of 0                                 All Occupations
# 1                          Management Occupations
# 2                                  Top Executives
# 3                                Chief Executives
# 4                                Chief Executives
#                           ...
# 1398    Refuse and Recyclable Material Collectors
# 1399            Tank Car, Truck, and Ship Loaders
# 1400            Tank Car, Truck, and Ship Loaders
# 1401        Miscellaneous Material Moving Workers
# 1402           Material Moving Workers, All Other
# Name: OCC_TITLE, Length: 1403, dtype: object>

# %%
wages_df.dtypes

# %%
wages_df.columns
# Out:
# Index(['AREA', 'AREA_TITLE', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE',
#        'I_GROUP', 'OWN_CODE', 'OCC_CODE', 'OCC_TITLE', 'O_GROUP', 'TOT_EMP',
#        'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'PCT_RPT',
#        'H_MEAN', 'A_MEAN', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_MEDIAN',
#        'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_MEDIAN', 'A_PCT75',
#        'A_PCT90', 'ANNUAL', 'HOURLY'],
#       dtype='object')

# %%
wages_df['A_PCT10'].unique()

#binning annual salary

# wages_df.describe()
# Out:
# array(['23,980', '47,860', '41,260', '60,300', '43,260', '17,850',
#        '63,270', '61,250', '63,350', '77,680', '61,090', '62,940',
#        '66,000', '60,400', '73,230', '59,210', '59,470', '59,010',
#        '95,220', '77,040', '64,150', '77,310', '58,570', '75,000',
#        '64,370', '47,040', '38,200', '60,050', '48,100', '31,200',
#        '61,480', '59,150', '47,630', '99,350', '36,630', '37,840',
#        '47,580', '37,020', '35,530', '60,780', '75,040', '68,970',
#        '30,740', '46,550', '46,670', '37,060', '42,260', '31,350',
#        '60,390', '39,060', '38,740', '47,370', '38,430', '42,490',
#        '41,490', '47,240', '38,950', '38,880', '37,570', '37,680',
#        '31,990', '22,880', '48,760', '45,160', '49,750', '50,190',
#        '30,170', '42,760', '31,340', '38,050', '43,720', '47,970',
#        '35,520', '49,330', '48,730', '57,900', '47,570', '47,330',
#        '59,370', '48,830', '33,290', '35,240', '32,520', '28,770',
# ...

# %%
print(wages_df["OCC_TITLE"].head(50))
# Out:
# 0                                       All Occupations
# 1                                Management Occupations
# 2                                        Top Executives
# 3                                      Chief Executives
# 4                                      Chief Executives
# 5                       General and Operations Managers
# 6                       General and Operations Managers
# 7                                           Legislators
# 8                                           Legislators
# 9     Advertising, Marketing, Promotions, Public Rel...
# 10                  Advertising and Promotions Managers
# 11                  Advertising and Promotions Managers
# 12                         Marketing and Sales Managers
# 13                                   Marketing Managers
# 14                                       Sales Managers
# 15            Public Relations and Fundraising Managers
# 16                            Public Relations Managers
# ...

# %%
print(wages_df["OCC_TITLE"].tail(50))
# Out:
# 1353                            Sailors and Marine Oilers
# 1354                            Sailors and Marine Oilers
# 1355                 Ship and Boat Captains and Operators
# 1356         Captains, Mates, and Pilots of Water Vessels
# 1357                                  Motorboat Operators
# 1358                                       Ship Engineers
# 1359                                       Ship Engineers
# 1360                         Other Transportation Workers
# 1361                              Bridge and Lock Tenders
# 1362                              Bridge and Lock Tenders
# 1363                                   Parking Attendants
# 1364                                   Parking Attendants
# 1365                    Transportation Service Attendants
# 1366         Automotive and Watercraft Service Attendants
# 1367                          Aircraft Service Attendants
# 1368                                  Traffic Technicians
# ...
