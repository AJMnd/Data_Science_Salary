# %%
import pandas as pd
import numpy as np

# %%
file_path = "wages/Partially Cleaned Salary Dataset.csv"
salary_df = pd.read_csv(file_path)
salary_df
# Out:
#       Unnamed: 0               Company Name  \
# 0              0                   Mu Sigma
# 1              1                        IBM
# 2              2  Tata Consultancy Services
# 3              3           Impact Analytics
# 4              4                  Accenture
# ...          ...                        ...
# 4334        4339                    TaiyōAI
# 4335        4340    Decimal Point Analytics
# 4336        4341                     MyWays
# 4337        4342  Market Pulse Technologies
# 4338        4343                    vPhrase
#
#                                  Job Title  Salaries Reported   Location  \
# 0                           Data Scientist                105  Bangalore
# 1                           Data Scientist                 95  Bangalore
# 2                           Data Scientist                 66  Bangalore
# 3                           Data Scientist                 40  Bangalore
# ...

# %%
salary_df.sum()
# Out:
# Unnamed: 0                                                     9415200
# Company Name         Mu SigmaIBMTata Consultancy ServicesImpact Ana...
# Job Title            Data ScientistData ScientistData ScientistData...
# Salaries Reported                                                12050
# Location             BangaloreBangaloreBangaloreBangaloreBangaloreB...
# Salary                                                    4859180826.0
# dtype: object

# %%
salary_df.columns.values.tolist()
# Out:
# ['Unnamed: 0',
#  'Company Name',
#  'Job Title',
#  'Salaries Reported',
#  'Location',
#  'Salary']
