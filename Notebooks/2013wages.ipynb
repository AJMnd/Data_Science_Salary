# %%
import pandas as pd
import numpy as np

# %%
file_path = "../newdata/oesm13st/state_M2013_dl.xls"
wages13_df = pd.read_excel(file_path)
wages13_df
# Out:
#        AREA  ST           STATE OCC_CODE  \
# 0         1  AL         Alabama  00-0000
# 1         1  AL         Alabama  11-0000
# 2         1  AL         Alabama  11-1011
# 3         1  AL         Alabama  11-1021
# 4         1  AL         Alabama  11-1031
# ...     ...  ..             ...      ...
# 37720    78  VI  Virgin Islands  53-6061
# 37721    78  VI  Virgin Islands  53-7051
# 37722    78  VI  Virgin Islands  53-7061
# 37723    78  VI  Virgin Islands  53-7062
# 37724    78  VI  Virgin Islands  53-7064
#
#                                                OCC_TITLE OCC_GROUP  TOT_EMP  \
# 0                                        All Occupations     total  1844080
# 1                                 Management Occupations     major    66820
# 2                                       Chief Executives  detailed     1300
# 3                        General and Operations Managers  detailed    26490
# 4                                            Legislators  detailed     1400
# ...

# %%
# Cleaning DataFrame by dropping unnecessary columns df.drop(columns=['B', 'C'], axis=1) axis=1 drops the whole column Stackoverflow

wages13_df = wages13_df.drop(columns=['AREA', 'ST', 'OCC_CODE', 'OCC_GROUP', 'EMP_PRSE', 'JOBS_1000', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_PCT75',  'A_PCT90', 'ANNUAL', 'HOURLY'], axis=1)
wages13_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37720  Virgin Islands  Transportation Attendants, Except Flight Atten...
# 37721  Virgin Islands             Industrial Truck and Tractor Operators
# 37722  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37723  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37724  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP LOC_Q H_MEAN  A_MEAN MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN  \
# ...

# %%
wages13_df = wages13_df.drop(columns=['LOC_Q', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25'], axis=1)
wages13_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37720  Virgin Islands  Transportation Attendants, Except Flight Atten...
# 37721  Virgin Islands             Industrial Truck and Tractor Operators
# 37722  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37723  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37724  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages13_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37720  Virgin Islands  Transportation Attendants, Except Flight Atten...
# 37721  Virgin Islands             Industrial Truck and Tractor Operators
# 37722  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37723  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37724  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages13_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37725 entries, 0 to 37724
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATE      37725 non-null  object
#  1   OCC_TITLE  37725 non-null  object
#  2   TOT_EMP    37725 non-null  object
#  3   H_MEAN     37725 non-null  object
#  4   A_MEAN     37725 non-null  object
#  5   H_MEDIAN   37725 non-null  object
#  6   A_MEDIAN   37725 non-null  object
# dtypes: object(7)
# memory usage: 2.0+ MB

# %%
# Getting rid of duplicates, Pandas documentation https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

wages13_df = wages13_df.drop_duplicates()

# %%
# Resetting index after dropping duplicates. https://stackoverflow.com/questions/28885073/reindexing-after-pandas-drop-duplicates
wages13_df = wages13_df.reset_index(drop=True)

# %%
wages13_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37720  Virgin Islands  Transportation Attendants, Except Flight Atten...
# 37721  Virgin Islands             Industrial Truck and Tractor Operators
# 37722  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37723  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37724  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
# 
wages13_df = wages13_df.dropna(axis=0, how='any')
wages13_df.head()
# Out:
#      STATE                        OCC_TITLE  TOT_EMP H_MEAN  A_MEAN H_MEDIAN  \
# 0  Alabama                  All Occupations  1844080  19.35   40240    14.61
# 1  Alabama           Management Occupations    66820  50.77  105600    44.53
# 2  Alabama                 Chief Executives     1300  88.34  183750    83.98
# 3  Alabama  General and Operations Managers    26490  57.62  119850    49.06
# 4  Alabama                      Legislators     1400      *   22660        *
#
#   A_MEDIAN
# 0    30390
# 1    92610
# 2   174690
# 3   102050
# 4    18510

# %%
# Rename the headers
wages13_df = wages13_df.rename(columns={"STATE" : "State",
"OCC_TITLE": "Occupation",
"TOT_EMP": "Total Employees",
"H_MEAN": "Hourly Mean",
"A_MEAN": "Annual Mean",
"H_MEDIAN": "Hourly Median",
"A_MEDIAN": "Annual Median",})

wages13_df.head()
# Out:
#      State                       Occupation Total Employees Hourly Mean  \
# 0  Alabama                  All Occupations         1844080       19.35
# 1  Alabama           Management Occupations           66820       50.77
# 2  Alabama                 Chief Executives            1300       88.34
# 3  Alabama  General and Operations Managers           26490       57.62
# 4  Alabama                      Legislators            1400           *
#
#   Annual Mean Hourly Median Annual Median
# 0       40240         14.61         30390
# 1      105600         44.53         92610
# 2      183750         83.98        174690
# 3      119850         49.06        102050
# 4       22660             *         18510

# %%
# Replacing special characters with nan and then dropping them.
wages13_df = (wages13_df
 .replace('#', np.nan)
 .replace('*', np.nan)
 .replace('**', np.nan)
              
 .dropna()
)

wages13_df.head()
# Out:
#      State                           Occupation  Total Employees  Hourly Mean  \
# 0  Alabama                      All Occupations        1844080.0        19.35
# 1  Alabama               Management Occupations          66820.0        50.77
# 2  Alabama                     Chief Executives           1300.0        88.34
# 3  Alabama      General and Operations Managers          26490.0        57.62
# 5  Alabama  Advertising and Promotions Managers            100.0        36.40
#
#    Annual Mean  Hourly Median  Annual Median
# 0      40240.0          14.61        30390.0
# 1     105600.0          44.53        92610.0
# 2     183750.0          83.98       174690.0
# 3     119850.0          49.06       102050.0
# 5      75710.0          34.73        72230.0

# %%
# Resetting the index after dropping rows.
wages13_df = wages13_df.reset_index(drop=True)

# %%
# Renaming the columns  
wages13_df.astype({
    'Hourly Mean':float,
    'Hourly Median':float,
    'Total Employees':float,
    'Annual Mean':float,
    'Annual Median':float,
}).dtypes
# Out:
# State               object
# Occupation          object
# Total Employees    float64
# Hourly Mean        float64
# Annual Mean        float64
# Hourly Median      float64
# Annual Median      float64
# dtype: object

# %%
wages13_df
# Out:
#                 State                                         Occupation  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                Advertising and Promotions Managers
# ...               ...                                                ...
# 33139  Virgin Islands       Captains, Mates, and Pilots of Water Vessels
# 33140  Virgin Islands       Automotive and Watercraft Service Attendants
# 33141  Virgin Islands                 Cleaners of Vehicles and Equipment
# 33142  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 33143  Virgin Islands                        Packers and Packagers, Hand
#
#        Total Employees  Hourly Mean  Annual Mean  Hourly Median  Annual Median
# ...

# %%
# Exporting Data Frame to csv 
wages13_df.to_csv("../Clean Data/2013wages.csv", index = False)
