# %%
import pandas as pd
import numpy as np

# %%
file_path = "../newdata/oesm18st/state_M2018_dl.xlsx"
wages18_df = pd.read_excel(file_path)
wages18_df
# Out:
#        AREA  ST           STATE OCC_CODE  \
# 0         1  AL         Alabama  00-0000
# 1         1  AL         Alabama  11-0000
# 2         1  AL         Alabama  11-1011
# 3         1  AL         Alabama  11-1021
# 4         1  AL         Alabama  11-1031
# ...     ...  ..             ...      ...
# 36892    78  VI  Virgin Islands  53-6031
# 36893    78  VI  Virgin Islands  53-6099
# 36894    78  VI  Virgin Islands  53-7051
# 36895    78  VI  Virgin Islands  53-7062
# 36896    78  VI  Virgin Islands  53-7064
#
#                                                OCC_TITLE OCC_GROUP  TOT_EMP  \
# 0                                        All Occupations     total  1943760
# 1                                 Management Occupations     major    73860
# 2                                       Chief Executives  detailed     1390
# 3                        General and Operations Managers  detailed    28600
# 4                                            Legislators  detailed      970
# ...

# %%
# Cleaning DataFrame by dropping unnecessary columns df.drop(columns=['B', 'C'], axis=1) axis=1 drops the whole column Stackoverflow

wages18_df = wages18_df.drop(columns=['AREA', 'OCC_CODE', 'OCC_GROUP', 'EMP_PRSE', 'JOBS_1000', 'LOC_Q', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_PCT75', 'A_PCT90', 'ANNUAL', 'HOURLY'], axis=1)

# %%
wages18_df
# Out:
#        ST           STATE                                          OCC_TITLE  \
# 0      AL         Alabama                                    All Occupations
# 1      AL         Alabama                             Management Occupations
# 2      AL         Alabama                                   Chief Executives
# 3      AL         Alabama                    General and Operations Managers
# 4      AL         Alabama                                        Legislators
# ...    ..             ...                                                ...
# 36892  VI  Virgin Islands       Automotive and Watercraft Service Attendants
# 36893  VI  Virgin Islands                  Transportation Workers, All Other
# 36894  VI  Virgin Islands             Industrial Truck and Tractor Operators
# 36895  VI  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 36896  VI  Virgin Islands                        Packers and Packagers, Hand
#
# ...

# %%
wages18_df = wages18_df.drop(columns=['ST', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25'], axis=1)
wages18_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 36892  Virgin Islands       Automotive and Watercraft Service Attendants
# 36893  Virgin Islands                  Transportation Workers, All Other
# 36894  Virgin Islands             Industrial Truck and Tractor Operators
# 36895  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 36896  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages18_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36897 entries, 0 to 36896
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATE      36897 non-null  object
#  1   OCC_TITLE  36897 non-null  object
#  2   TOT_EMP    36897 non-null  object
#  3   H_MEAN     36897 non-null  object
#  4   A_MEAN     36897 non-null  object
#  5   H_MEDIAN   36897 non-null  object
#  6   A_MEDIAN   36897 non-null  object
# dtypes: object(7)
# memory usage: 2.0+ MB

# %%
# Getting rid of duplicates, Pandas documentation https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

wages18_df = wages18_df.drop_duplicates()

# %%
# Resetting index after dropping duplicates. https://stackoverflow.com/questions/28885073/reindexing-after-pandas-drop-duplicates
wages18_df = wages18_df.reset_index(drop=True)

# %%
wages18_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 36892  Virgin Islands       Automotive and Watercraft Service Attendants
# 36893  Virgin Islands                  Transportation Workers, All Other
# 36894  Virgin Islands             Industrial Truck and Tractor Operators
# 36895  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 36896  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
# 
wages18_df = wages18_df.dropna(axis=0, how='any')
wages18_df.head()
# Out:
#      STATE                        OCC_TITLE  TOT_EMP H_MEAN  A_MEAN H_MEDIAN  \
# 0  Alabama                  All Occupations  1943760  21.05   43790    16.22
# 1  Alabama           Management Occupations    73860  52.73  109680    46.01
# 2  Alabama                 Chief Executives     1390  98.36  204590    91.31
# 3  Alabama  General and Operations Managers    28600  56.94  118440    48.55
# 4  Alabama                      Legislators      970      *   31760        *
#
#   A_MEDIAN
# 0    33740
# 1    95710
# 2   189920
# 3   100980
# 4    19210

# %%
# Rename the headers
wages18_df = wages18_df.rename(columns={"STATE": "State",
"OCC_TITLE": "Occupation",
"TOT_EMP": "Total Employees",
"H_MEAN": "Hourly Mean",
"A_MEAN": "Annual Mean",
"H_MEDIAN": "Hourly Median",
"A_MEDIAN": "Annual Median",})

wages18_df.head()
# Out:
#      State                           Occupation  Total Employees  Hourly Mean  \
# 0  Alabama                      All Occupations        1943760.0        21.05
# 1  Alabama               Management Occupations          73860.0        52.73
# 2  Alabama                     Chief Executives           1390.0        98.36
# 3  Alabama      General and Operations Managers          28600.0        56.94
# 4  Alabama  Advertising and Promotions Managers             50.0        53.12
#
#    Annual Mean  Hourly Median  Annual Median
# 0      43790.0          16.22        33740.0
# 1     109680.0          46.01        95710.0
# 2     204590.0          91.31       189920.0
# 3     118440.0          48.55       100980.0
# 4     110480.0          54.62       113610.0

# %%
# Replacing special characters with nan and then dropping them.
wages18_df = (wages18_df
 .replace('#', np.nan)
 .replace('*', np.nan)
 .replace('**', np.nan)
              
 .dropna()
)

wages18_df.head()
# Out:
#      State                           Occupation  Total Employees  Hourly Mean  \
# 0  Alabama                      All Occupations        1943760.0        21.05
# 1  Alabama               Management Occupations          73860.0        52.73
# 2  Alabama                     Chief Executives           1390.0        98.36
# 3  Alabama      General and Operations Managers          28600.0        56.94
# 4  Alabama  Advertising and Promotions Managers             50.0        53.12
#
#    Annual Mean  Hourly Median  Annual Median
# 0      43790.0          16.22        33740.0
# 1     109680.0          46.01        95710.0
# 2     204590.0          91.31       189920.0
# 3     118440.0          48.55       100980.0
# 4     110480.0          54.62       113610.0

# %%
# Resetting the index after dropping rows.
wages18_df = wages18_df.reset_index(drop=True)

# %%
# Renaming the columns  
wages18_df.astype({
    'Hourly Mean':float,
    'Hourly Median':float,
    'Total Employees':float,
    'Annual Mean':float,
    'Annual Median':float,
}).dtypes
# Out:
# State               object
# Occupation          object
# Total Employees    float64
# Hourly Mean        float64
# Annual Mean        float64
# Hourly Median      float64
# Annual Median      float64
# dtype: object

# %%
wages18_df
# Out:
#                 State                                    Occupation  \
# 0             Alabama                               All Occupations
# 1             Alabama                        Management Occupations
# 2             Alabama                              Chief Executives
# 3             Alabama               General and Operations Managers
# 4             Alabama           Advertising and Promotions Managers
# ...               ...                                           ...
# 32102  Virgin Islands                   Taxi Drivers and Chauffeurs
# 32103  Virgin Islands  Captains, Mates, and Pilots of Water Vessels
# 32104  Virgin Islands  Automotive and Watercraft Service Attendants
# 32105  Virgin Islands        Industrial Truck and Tractor Operators
# 32106  Virgin Islands                   Packers and Packagers, Hand
#
#        Total Employees  Hourly Mean  Annual Mean  Hourly Median  Annual Median
# ...

# %%
# Exporting Data Frame to csv 
wages18_df.to_csv("../Clean Data/2018wages.csv", index = False)
