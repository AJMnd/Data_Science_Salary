# %%
import pandas as pd
import numpy as np

# %%
file_path = "../newdata/oesm16st/state_M2016_dl.xlsx"
wages16_df = pd.read_excel(file_path)
wages16_df
# Out:
#        AREA  ST           STATE OCC_CODE  \
# 0         1  AL         Alabama  00-0000
# 1         1  AL         Alabama  11-0000
# 2         1  AL         Alabama  11-1011
# 3         1  AL         Alabama  11-1021
# 4         1  AL         Alabama  11-1031
# ...     ...  ..             ...      ...
# 37556    78  VI  Virgin Islands  53-5021
# 37557    78  VI  Virgin Islands  53-6031
# 37558    78  VI  Virgin Islands  53-7061
# 37559    78  VI  Virgin Islands  53-7062
# 37560    78  VI  Virgin Islands  53-7064
#
#                                                OCC_TITLE OCC_GROUP  TOT_EMP  \
# 0                                        All Occupations     total  1912990
# 1                                 Management Occupations     major    70090
# 2                                       Chief Executives  detailed     1030
# 3                        General and Operations Managers  detailed    26930
# 4                                            Legislators  detailed     1210
# ...

# %%
# Cleaning DataFrame by dropping unnecessary columns df.drop(columns=['B', 'C'], axis=1) axis=1 drops the whole column Stackoverflow

wages16_df = wages16_df.drop(columns=['AREA', 'ST', 'OCC_CODE', 'OCC_GROUP', 'EMP_PRSE', 'JOBS_1000', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_PCT75',  'A_PCT90', 'ANNUAL', 'HOURLY'], axis=1)

# %%
wages16_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37556  Virgin Islands       Captains, Mates, and Pilots of Water Vessels
# 37557  Virgin Islands       Automotive and Watercraft Service Attendants
# 37558  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37559  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37560  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  LOC_Q  H_MEAN  A_MEAN MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN  \
# ...

# %%
wages16_df = wages16_df.drop(columns=['LOC_Q', 'MEAN_PRSE', 'H_PCT10', 'H_PCT25'], axis=1)
wages16_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37556  Virgin Islands       Captains, Mates, and Pilots of Water Vessels
# 37557  Virgin Islands       Automotive and Watercraft Service Attendants
# 37558  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37559  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37560  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages16_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37556  Virgin Islands       Captains, Mates, and Pilots of Water Vessels
# 37557  Virgin Islands       Automotive and Watercraft Service Attendants
# 37558  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37559  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37560  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages16_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37561 entries, 0 to 37560
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATE      37561 non-null  object
#  1   OCC_TITLE  37561 non-null  object
#  2   TOT_EMP    37561 non-null  object
#  3   H_MEAN     37561 non-null  object
#  4   A_MEAN     37561 non-null  object
#  5   H_MEDIAN   37561 non-null  object
#  6   A_MEDIAN   37561 non-null  object
# dtypes: object(7)
# memory usage: 2.0+ MB

# %%
# Getting rid of duplicates, Pandas documentation https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

wages16_df = wages16_df.drop_duplicates()

# %%
# Resetting index after dropping duplicates. https://stackoverflow.com/questions/28885073/reindexing-after-pandas-drop-duplicates
wages16_df = wages16_df.reset_index(drop=True)

# %%
wages16_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37556  Virgin Islands       Captains, Mates, and Pilots of Water Vessels
# 37557  Virgin Islands       Automotive and Watercraft Service Attendants
# 37558  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37559  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37560  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
# 
wages16_df = wages16_df.dropna(axis=0, how='any')
wages16_df.head()
# Out:
#      STATE                        OCC_TITLE  TOT_EMP  H_MEAN  A_MEAN H_MEDIAN  \
# 0  Alabama                  All Occupations  1912990   20.44   42510    15.43
# 1  Alabama           Management Occupations    70090   52.98  110210    46.09
# 2  Alabama                 Chief Executives     1030  100.63  209300    94.59
# 3  Alabama  General and Operations Managers    26930   58.86  122420    49.53
# 4  Alabama                      Legislators     1210       *   23390        *
#
#   A_MEDIAN
# 0    32100
# 1    95870
# 2   196750
# 3   103030
# 4    18560

# %%
# Rename the headers
wages16_df = wages16_df.rename(columns={"STATE" : "State",
"OCC_TITLE": "Occupation",
"TOT_EMP": "Total Employees",
"H_MEAN": "Hourly Mean",
"A_MEAN": "Annual Mean",
"H_MEDIAN": "Hourly Median",
"A_MEDIAN": "Annual Median",})

wages16_df.head()
# Out:
#      State                       Occupation Total Employees Hourly Mean  \
# 0  Alabama                  All Occupations         1912990       20.44
# 1  Alabama           Management Occupations           70090       52.98
# 2  Alabama                 Chief Executives            1030      100.63
# 3  Alabama  General and Operations Managers           26930       58.86
# 4  Alabama                      Legislators            1210           *
#
#   Annual Mean Hourly Median Annual Median
# 0       42510         15.43         32100
# 1      110210         46.09         95870
# 2      209300         94.59        196750
# 3      122420         49.53        103030
# 4       23390             *         18560

# %%
# Replacing special characters with nan and then dropping them.
wages16_df = (wages16_df
 .replace('#', np.nan)
 .replace('*', np.nan)
 .replace('**', np.nan)
              
 .dropna()
)

wages16_df.head()
# Out:
#      State                       Occupation  Total Employees  Hourly Mean  \
# 0  Alabama                  All Occupations        1912990.0        20.44
# 1  Alabama           Management Occupations          70090.0        52.98
# 2  Alabama                 Chief Executives           1030.0       100.63
# 3  Alabama  General and Operations Managers          26930.0        58.86
# 6  Alabama               Marketing Managers            530.0        69.03
#
#    Annual Mean  Hourly Median  Annual Median
# 0      42510.0          15.43        32100.0
# 1     110210.0          46.09        95870.0
# 2     209300.0          94.59       196750.0
# 3     122420.0          49.53       103030.0
# 6     143590.0          57.82       120270.0

# %%
# Resetting the index after dropping rows.
wages16_df = wages16_df.reset_index(drop=True)

# %%
# Renaming the columns  
wages16_df.astype({
    'Hourly Mean':float,
    'Hourly Median':float,
    'Total Employees':float,
    'Annual Mean':float,
    'Annual Median':float,
}).dtypes
# Out:
# State               object
# Occupation          object
# Total Employees    float64
# Hourly Mean        float64
# Annual Mean        float64
# Hourly Median      float64
# Annual Median      float64
# dtype: object

# %%
wages16_df
# Out:
#                 State                                         Occupation  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                 Marketing Managers
# ...               ...                                                ...
# 32921  Virgin Islands       Captains, Mates, and Pilots of Water Vessels
# 32922  Virgin Islands       Automotive and Watercraft Service Attendants
# 32923  Virgin Islands                 Cleaners of Vehicles and Equipment
# 32924  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 32925  Virgin Islands                        Packers and Packagers, Hand
#
#        Total Employees  Hourly Mean  Annual Mean  Hourly Median  Annual Median
# ...

# %%
# Exporting Data Frame to csv 
wages16_df.to_csv("../Clean Data/2016wages.csv", index = False)
