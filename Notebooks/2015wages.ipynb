# %%
import pandas as pd
import numpy as np

# %%
file_path = "../newdata/oesm15st/state_M2015_dl.xlsx"
wages15_df = pd.read_excel(file_path)
wages15_df
# Out:
#        AREA  ST           STATE OCC_CODE  \
# 0         1  AL         Alabama  00-0000
# 1         1  AL         Alabama  11-0000
# 2         1  AL         Alabama  11-1011
# 3         1  AL         Alabama  11-1021
# 4         1  AL         Alabama  11-1031
# ...     ...  ..             ...      ...
# 37637    78  VI  Virgin Islands  53-6099
# 37638    78  VI  Virgin Islands  53-7051
# 37639    78  VI  Virgin Islands  53-7061
# 37640    78  VI  Virgin Islands  53-7062
# 37641    78  VI  Virgin Islands  53-7064
#
#                                                OCC_TITLE OCC_GROUP  TOT_EMP  \
# 0                                        All Occupations     total  1883310
# 1                                 Management Occupations     major    69100
# 2                                       Chief Executives  detailed     1100
# 3                        General and Operations Managers  detailed    27240
# 4                                            Legislators  detailed     1430
# ...

# %%
# Cleaning DataFrame by dropping unnecessary columns df.drop(columns=['B', 'C'], axis=1) axis=1 drops the whole column Stackoverflow

wages15_df = wages15_df.drop(columns=['AREA', 'ST', 'OCC_CODE', 'OCC_GROUP', 'EMP_PRSE', 'JOBS_1000', 'LOC_Q', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_PCT75', 'A_PCT90', 'ANNUAL', 'HOURLY'], axis=1)
wages15_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37637  Virgin Islands                  Transportation Workers, All Other
# 37638  Virgin Islands             Industrial Truck and Tractor Operators
# 37639  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37640  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37641  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN A_MEDIAN
# ...

# %%
wages15_df = wages15_df.drop(columns=['MEAN_PRSE', 'H_PCT10', 'H_PCT25', 'H_PCT25'], axis=1)
wages15_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37637  Virgin Islands                  Transportation Workers, All Other
# 37638  Virgin Islands             Industrial Truck and Tractor Operators
# 37639  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37640  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37641  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages15_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37637  Virgin Islands                  Transportation Workers, All Other
# 37638  Virgin Islands             Industrial Truck and Tractor Operators
# 37639  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37640  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37641  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages15_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37642 entries, 0 to 37641
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   STATE      37642 non-null  object
#  1   OCC_TITLE  37642 non-null  object
#  2   TOT_EMP    37642 non-null  object
#  3   H_MEAN     37642 non-null  object
#  4   A_MEAN     37642 non-null  object
#  5   H_MEDIAN   37642 non-null  object
#  6   A_MEDIAN   37642 non-null  object
# dtypes: object(7)
# memory usage: 2.0+ MB

# %%
# Getting rid of duplicates, Pandas documentation https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

wages15_df = wages15_df.drop_duplicates()

# %%
# Resetting index after dropping duplicates. https://stackoverflow.com/questions/28885073/reindexing-after-pandas-drop-duplicates
wages15_df = wages15_df.reset_index(drop=True)

# %%
wages15_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37637  Virgin Islands                  Transportation Workers, All Other
# 37638  Virgin Islands             Industrial Truck and Tractor Operators
# 37639  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37640  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37641  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
# dropping unecessary rows
wages15_df = wages15_df.dropna(axis=0, how='any')
wages15_df
# Out:
#                 STATE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 37637  Virgin Islands                  Transportation Workers, All Other
# 37638  Virgin Islands             Industrial Truck and Tractor Operators
# 37639  Virgin Islands                 Cleaners of Vehicles and Equipment
# 37640  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 37641  Virgin Islands                        Packers and Packagers, Hand
#
#        TOT_EMP  H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
# Rename the headers
wages15_df = wages15_df.rename(columns={"STATE" : "State",
"OCC_TITLE": "Occupation",
"TOT_EMP": "Total Employees",
"H_MEAN": "Hourly Mean",
"A_MEAN": "Annual Mean",
"H_MEDIAN": "Hourly Median",
"A_MEDIAN": "Annual Median",})

wages15_df.head()
# Out:
#      State                       Occupation Total Employees Hourly Mean  \
# 0  Alabama                  All Occupations         1883310       20.15
# 1  Alabama           Management Occupations           69100       52.79
# 2  Alabama                 Chief Executives            1100      101.21
# 3  Alabama  General and Operations Managers           27240       58.85
# 4  Alabama                      Legislators            1430           *
#
#   Annual Mean Hourly Median Annual Median
# 0       41920         15.17         31550
# 1      109800          45.9         95470
# 2      210530             #             #
# 3      122410          49.2        102330
# 4       22690             *         18380

# %%
# Replacing special characters with nan and then dropping them.
wages15_df = (wages15_df
 .replace('#', np.nan)
 .replace('*', np.nan)
 .replace('**', np.nan)
              
 .dropna()
)

wages15_df.head()
# Out:
#      State                           Occupation  Total Employees  Hourly Mean  \
# 0  Alabama                      All Occupations        1883310.0        20.15
# 1  Alabama               Management Occupations          69100.0        52.79
# 3  Alabama      General and Operations Managers          27240.0        58.85
# 5  Alabama  Advertising and Promotions Managers             50.0        53.65
# 6  Alabama                   Marketing Managers            550.0        66.79
#
#    Annual Mean  Hourly Median  Annual Median
# 0      41920.0          15.17        31550.0
# 1     109800.0          45.90        95470.0
# 3     122410.0          49.20       102330.0
# 5     111590.0          41.29        85890.0
# 6     138920.0          57.58       119770.0

# %%
# Resetting the index after dropping rows.
wages15_df = wages15_df.reset_index(drop=True)

# %%
# Renaming the columns  
wages15_df.astype({
    'Hourly Mean':float,
    'Hourly Median':float,
    'Total Employees':float,
    'Annual Mean':float,
    'Annual Median':float,
}).dtypes
# Out:
# State               object
# Occupation          object
# Total Employees    float64
# Hourly Mean        float64
# Annual Mean        float64
# Hourly Median      float64
# Annual Median      float64
# dtype: object

# %%
wages15_df
# Out:
#                 State                                         Occupation  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                    General and Operations Managers
# 3             Alabama                Advertising and Promotions Managers
# 4             Alabama                                 Marketing Managers
# ...               ...                                                ...
# 32965  Virgin Islands       Captains, Mates, and Pilots of Water Vessels
# 32966  Virgin Islands       Automotive and Watercraft Service Attendants
# 32967  Virgin Islands                 Cleaners of Vehicles and Equipment
# 32968  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 32969  Virgin Islands                        Packers and Packagers, Hand
#
#        Total Employees  Hourly Mean  Annual Mean  Hourly Median  Annual Median
# ...

# %%
# Exporting Data Frame to csv 
wages15_df.to_csv("../Clean Data/2015wages.csv", index = False)
