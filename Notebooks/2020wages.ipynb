# %%
import pandas as pd
import numpy as np

# %%
file_path = "../newdata/oesm20st/state_M2020_dl.xlsx"
wages20_df = pd.read_excel(file_path)
wages20_df
# Out:
#        AREA      AREA_TITLE  AREA_TYPE PRIM_STATE  NAICS     NAICS_TITLE  \
# 0         1         Alabama          2         AL      0  Cross-industry
# 1         1         Alabama          2         AL      0  Cross-industry
# 2         1         Alabama          2         AL      0  Cross-industry
# 3         1         Alabama          2         AL      0  Cross-industry
# 4         1         Alabama          2         AL      0  Cross-industry
# ...     ...             ...        ...        ...    ...             ...
# 36080    78  Virgin Islands          3         VI      0  Cross-industry
# 36081    78  Virgin Islands          3         VI      0  Cross-industry
# 36082    78  Virgin Islands          3         VI      0  Cross-industry
# 36083    78  Virgin Islands          3         VI      0  Cross-industry
# 36084    78  Virgin Islands          3         VI      0  Cross-industry
#
#               I_GROUP  OWN_CODE OCC_CODE  \
# 0      cross-industry      1235  00-0000
# ...

# %%
# Cleaning DataFrame by dropping unnecessary columns df.drop(columns=['B', 'C'], axis=1) axis=1 drops the whole column Stackoverflow

wages20_df = wages20_df.drop(columns=['AREA', 'AREA_TYPE', 'PRIM_STATE', 'NAICS', 'NAICS_TITLE', 'I_GROUP', 'OWN_CODE', 'OCC_CODE'], axis=1)

# %%
wages20_df
# Out:
#            AREA_TITLE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 36080  Virgin Islands                          Crane and Tower Operators
# 36081  Virgin Islands             Industrial Truck and Tractor Operators
# 36082  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 36083  Virgin Islands                        Packers and Packagers, Hand
# 36084  Virgin Islands                         Stockers and Order Fillers
#
#         O_GROUP  TOT_EMP EMP_PRSE JOBS_1000 LOC_QUOTIENT  PCT_TOTAL H_MEAN  \
# ...

# %%
wages20_df = wages20_df.drop(columns=['O_GROUP', 'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_PCT75', 'A_PCT90', 'ANNUAL', 'HOURLY'], axis=1)
wages20_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9184\728220832.py in <module>
# ----> 1 wages20_df = wages20_df.drop(columns=['O_GROUP', 'EMP_PRSE', 'JOBS_1000', 'LOC_QUOTIENT', 'PCT_TOTAL', 'H_PCT75', 'H_PCT90', 'A_PCT10', 'A_PCT25', 'A_PCT75', 'A_PCT90', 'ANNUAL', 'HOURLY'], axis=1)
#       2 wages20_df
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ...

# %%
wages20_df
# Out:
#            AREA_TITLE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 36080  Virgin Islands                          Crane and Tower Operators
# 36081  Virgin Islands             Industrial Truck and Tractor Operators
# 36082  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 36083  Virgin Islands                        Packers and Packagers, Hand
# 36084  Virgin Islands                         Stockers and Order Fillers
#
#        TOT_EMP H_MEAN  A_MEAN MEAN_PRSE H_PCT10 H_PCT25 H_MEDIAN A_MEDIAN
# ...

# %%
wages20_df = wages20_df.drop(columns=['MEAN_PRSE', 'H_PCT10', 'H_PCT25'], axis=1)
wages20_df
# Out:
#            AREA_TITLE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 36080  Virgin Islands                          Crane and Tower Operators
# 36081  Virgin Islands             Industrial Truck and Tractor Operators
# 36082  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 36083  Virgin Islands                        Packers and Packagers, Hand
# 36084  Virgin Islands                         Stockers and Order Fillers
#
#        TOT_EMP H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
wages20_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36085 entries, 0 to 36084
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   AREA_TITLE  36085 non-null  object
#  1   OCC_TITLE   36085 non-null  object
#  2   TOT_EMP     36085 non-null  object
#  3   H_MEAN      36085 non-null  object
#  4   A_MEAN      36085 non-null  object
#  5   H_MEDIAN    36085 non-null  object
#  6   A_MEDIAN    36085 non-null  object
# dtypes: object(7)
# memory usage: 1.9+ MB

# %%
# Getting rid of duplicates, Pandas documentation https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.drop_duplicates.html

wages20_df = wages20_df.drop_duplicates()

# %%
# Resetting index after dropping duplicates. https://stackoverflow.com/questions/28885073/reindexing-after-pandas-drop-duplicates
wages20_df = wages20_df.reset_index(drop=True)

# %%
wages20_df
# Out:
#            AREA_TITLE                                          OCC_TITLE  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                                        Legislators
# ...               ...                                                ...
# 36080  Virgin Islands                          Crane and Tower Operators
# 36081  Virgin Islands             Industrial Truck and Tractor Operators
# 36082  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 36083  Virgin Islands                        Packers and Packagers, Hand
# 36084  Virgin Islands                         Stockers and Order Fillers
#
#        TOT_EMP H_MEAN  A_MEAN H_MEDIAN A_MEDIAN
# ...

# %%
# 
wages20_df = wages20_df.dropna(axis=0, how='any')
wages20_df.head()
# Out:
#   AREA_TITLE                        OCC_TITLE  TOT_EMP H_MEAN  A_MEAN  \
# 0    Alabama                  All Occupations  1903210  22.52   46840
# 1    Alabama           Management Occupations    87110   52.9  110040
# 2    Alabama                 Chief Executives     1160  84.09  174910
# 3    Alabama  General and Operations Managers    31170  58.56  121800
# 4    Alabama                      Legislators     1150      *   28840
#
#   H_MEDIAN A_MEDIAN
# 0    17.43    36250
# 1    45.73    95120
# 2    77.55   161290
# 3    48.64   101170
# 4        *    18820

# %%
# Rename the headers
wages20_df = wages20_df.rename(columns={"AREA_TITLE" : "State",
"OCC_TITLE": "Occupation",
"TOT_EMP": "Total Employees",
"H_MEAN": "Hourly Mean",
"A_MEAN": "Annual Mean",
"H_MEDIAN": "Hourly Median",
"A_MEDIAN": "Annual Median",})

wages20_df.head()
# Out:
#      State                       Occupation Total Employees Hourly Mean  \
# 0  Alabama                  All Occupations         1903210       22.52
# 1  Alabama           Management Occupations           87110        52.9
# 2  Alabama                 Chief Executives            1160       84.09
# 3  Alabama  General and Operations Managers           31170       58.56
# 4  Alabama                      Legislators            1150           *
#
#   Annual Mean Hourly Median Annual Median
# 0       46840         17.43         36250
# 1      110040         45.73         95120
# 2      174910         77.55        161290
# 3      121800         48.64        101170
# 4       28840             *         18820

# %%
# Replacing special characters with nan and then dropping them.
wages20_df = (wages20_df
 .replace('#', np.nan)
 .replace('*', np.nan)
 .replace('**', np.nan)
              
 .dropna()
)

wages20_df.head()
# Out:
#      State                           Occupation  Total Employees  Hourly Mean  \
# 0  Alabama                      All Occupations        1903210.0        22.52
# 1  Alabama               Management Occupations          87110.0        52.90
# 2  Alabama                     Chief Executives           1160.0        84.09
# 3  Alabama      General and Operations Managers          31170.0        58.56
# 5  Alabama  Advertising and Promotions Managers             70.0        54.81
#
#    Annual Mean  Hourly Median  Annual Median
# 0      46840.0          17.43        36250.0
# 1     110040.0          45.73        95120.0
# 2     174910.0          77.55       161290.0
# 3     121800.0          48.64       101170.0
# 5     114000.0          51.46       107030.0

# %%
# Resetting the index after dropping rows.
wages20_df = wages20_df.reset_index(drop=True)

# %%
# Renaming the columns  
wages20_df.astype({
    'Hourly Mean':float,
    'Hourly Median':float,
    'Total Employees':float,
    'Annual Mean':float,
    'Annual Median':float,
}).dtypes
# Out:
# State               object
# Occupation          object
# Total Employees    float64
# Hourly Mean        float64
# Annual Mean        float64
# Hourly Median      float64
# Annual Median      float64
# dtype: object

# %%
wages20_df
# Out:
#                 State                                         Occupation  \
# 0             Alabama                                    All Occupations
# 1             Alabama                             Management Occupations
# 2             Alabama                                   Chief Executives
# 3             Alabama                    General and Operations Managers
# 4             Alabama                Advertising and Promotions Managers
# ...               ...                                                ...
# 31149  Virgin Islands                          Crane and Tower Operators
# 31150  Virgin Islands             Industrial Truck and Tractor Operators
# 31151  Virgin Islands  Laborers and Freight, Stock, and Material Move...
# 31152  Virgin Islands                        Packers and Packagers, Hand
# 31153  Virgin Islands                         Stockers and Order Fillers
#
#        Total Employees  Hourly Mean  Annual Mean  Hourly Median  Annual Median
# ...

# %%
# Exporting Data Frame to csv 
wages20_df.to_csv("../Clean Data/2020wages.csv", index = False)
